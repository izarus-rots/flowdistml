# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
# run normalization runs (1-dim DOE, linear, since only one param for cyCombine)
import subprocess

cofactors = [5, 50, 150, 500, 1000, 5000]
for cofactor in cofactors:
    subprocess.run(f"mkdir normalized_{cofactor}_comb/", shell=True)
    subprocess.run(f"Rscript ../flownorms/cycombine/cycombine.r --input ../flownorms/validation_data/combined_CLL/ --output normalized_{cofactor}_comb/ --method scale --cofactor {cofactor}", shell=True)
